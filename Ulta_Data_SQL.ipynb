# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
import urllib.parse
from urllib.parse import quote_plus as urlquote
engine = create_engine('postgres://user:%s@host/database' % urlquote('badpass'))

# %%
blush_csv_path = "blush.csv"
eyeshadow_csv_path = "eyeshadow.csv"
lipstick_csv_path = "lipstick.csv"
ulta_csv_path = "ulta.csv"

blush_df = pd.read_csv(blush_csv_path)
eyeshadow_df = pd.read_csv(eyeshadow_csv_path)
lipstick_df = pd.read_csv(lipstick_csv_path)
ulta_df = pd.read_csv(ulta_csv_path)

Blush_eyeshadow_df = pd.merge(blush_df,eyeshadow_df, how='outer')
Blush_eyeshadow_lipsick_df = pd.merge(Blush_eyeshadow_df, lipstick_df, how='outer')
Ulta_Products_df = pd.merge(Blush_eyeshadow_lipsick_df, ulta_df, how='outer')
Ulta_Products_df
# Out:
#                        Brand  \
# 0            KYLIE COSMETICS
# 1                       NARS
# 2                      Tarte
# 3                   Smashbox
# 4                     Milani
# ..                       ...
# 378                  L'Oréal
# 379  NYX Professional Makeup
# 380                     ULTA
# 381                    Tarte
# 382                CoverGirl
#
#                                                Product Product Type    Price  \
# 0                                                Blush        Blush  $18.00
# 1                                                Blush        Blush  $30.00
# 2                         Amazonian Clay 12 Hour Blush        Blush  $29.00
# 3                                   Halo Cheek Palette        Blush  $35.00
# 4                                          Baked Blush        Blush   $9.49
# ..                                                 ...          ...      ...
# ...

# %%
Ulta_products_cols = ["Brand","Product", "Product Type", "Price", "Rating", "Image URL"]
Ulta_Products_transformed = Ulta_Products_df[Ulta_products_cols].copy()

Ulta_Products_transformed = Ulta_Products_transformed.rename(columns= {"Brand" : "Brand",
                                                          "Product" : "Product", 
                                                          "Product Type" : "Product_Type", 
                                                          "Price" :      "Price", 
                                                          "Rating" :   "Rating", 
                                                          "Image URL" :     "Image_URL"}) 
Ulta_Products_transformed.head()
# Out:
#              Brand                       Product Product_Type    Price  \
# 0  KYLIE COSMETICS                         Blush        Blush  $18.00
# 1             NARS                         Blush        Blush  $30.00
# 2            Tarte  Amazonian Clay 12 Hour Blush        Blush  $29.00
# 3         Smashbox            Halo Cheek Palette        Blush  $35.00
# 4           Milani                   Baked Blush        Blush   $9.49
#
#                Rating                                          Image_URL
# 0  3.8 out of 5 stars  https://images.ulta.com/is/image/Ulta/2543053?...
# 1  4.6 out of 5 stars  https://images.ulta.com/is/image/Ulta/2503561?...
# 2  4.6 out of 5 stars  https://images.ulta.com/is/image/Ulta/2230172?...
# 3  4.2 out of 5 stars  https://images.ulta.com/is/image/Ulta/2569811?...
# 4  4.6 out of 5 stars  https://images.ulta.com/is/image/Ulta/2519994?...

# %%
engine = create_engine(f'postgres://postgres:Cellxan69$$@localhost:5432/Ulta_Product_Analysis')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...

# %%
Ulta_Products_transformed.to_sql(name='ulta_products', con=engine, if_exists='append', index= False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~/.local/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...
